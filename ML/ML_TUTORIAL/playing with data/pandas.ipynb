# %%
import pandas as pd

# %%
df = pd.read_csv("titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.PassengerId.dtype
# Out:
# dtype('int64')

# %%
import pandas as pd
df = pd.read_csv("titanic_dataset.csv")
df.PassengerId.dtype
df.dtypes
df[:7]
df.head(7)
df.to_excel("titanic.xlsx", sheet="")

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[:7]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.to_excel("titanic.xlsx", sheet_name="hai", index=False)

# %%
df1 = pd.read_excel("./titanic.xlsx")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df1.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df1[["Age"]]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
age = df1[["Age"]] >36
age
# Out:
#        Age
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# ..     ...
# 886  False
# 887  False
# 888  False
# 889  False
# 890  False
#
# [891 rows x 1 columns]

# %%
import numpy as np
print(np)
# Out:
# <module 'numpy' from 'C:\\Users\\amalv\\anaconda3\\jupyter\\lib\\site-packages\\numpy\\__init__.py'>

# %%
type(df1.Age)
# Out:
# pandas.core.series.Series

# %%
age_1 = np.where(df1.Age>36)
age_1
# Out:
# (array([  1,   6,  11,  13,  15,  25,  30,  33,  35,  40,  52,  54,  61,
#          62,  92,  94,  96, 104, 108, 110, 116, 124, 129, 132, 137, 148,
#         149, 150, 152, 153, 155, 160, 161, 167, 170, 174, 177, 187, 188,
#         194, 195, 197, 203, 209, 217, 222, 224, 232, 236, 245, 248, 249,
#         252, 254, 259, 262, 263, 268, 272, 273, 275, 276, 280, 288, 299,
#         314, 317, 319, 326, 331, 332, 337, 338, 339, 346, 349, 357, 360,
#         362, 366, 380, 397, 400, 406, 414, 432, 434, 438, 440, 449, 453,
#         456, 458, 460, 462, 463, 465, 467, 471, 482, 483, 487, 492, 493,
#         496, 503, 513, 515, 523, 525, 526, 528, 536, 544, 545, 555, 556,
#         558, 561, 570, 571, 577, 581, 582, 586, 587, 591, 592, 594, 597,
#         599, 603, 609, 610, 621, 625, 626, 630, 631, 638, 645, 647, 659,
#         660, 661, 662, 668, 670, 672, 678, 684, 694, 695, 696, 698, 699,
#         705, 706, 707, 712, 714, 716, 723, 736, 745, 754, 761, 765, 771,
# ...

# %%
df1['Age'].shape
# Out:
# (891,)

# %%
df1[['Age','Sex']]
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 886  27.0    male
# 887  19.0  female
# 888   NaN  female
# 889  26.0    male
# 890  32.0    male
#
# [891 rows x 2 columns]

# %%
df1[['Age','Sex']].shape
# Out:
# (891, 2)

# %%
age_36 = df1[df1["Age"] > 36]

# %%
age_36 = df1[df1['Age'] > 36 & df['Pclass']==2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23128\1746562814.py in <module>
# ----> 1 age_36 = df1[df1['Age'] > 36 & df['Pclass']==2]
#
# ~\anaconda3\jupyter\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
age_36[age_36['Pclass']==2]
# Out:
#      PassengerId  Survived  Pclass  \
# 15            16         1       2
# 33            34         0       2
# 148          149         0       2
# 149          150         0       2
# 150          151         0       2
# 161          162         1       2
# 217          218         0       2
# 232          233         0       2
# 236          237         0       2
# 249          250         0       2
# 259          260         1       2
# 272          273         1       2
# 288          289         1       2
# 314          315         0       2
# 317          318         0       2
# 346          347         1       2
# 357          358         0       2
# 397          398         0       2
# 432          433         1       2
# 440          441         1       2
# 458          459         1       2
# 463          464         0       2
# 526          527         1       2
# 570          571         1       2
# 582          583         0       2
# ...

# %%
age_36[age_36['Pclass']==2].shape
# Out:
# (43, 12)

# %%
class_23 = df1[df1["Pclass"].isin([2,3])]

# %%
class_23
# Out:
#      PassengerId  Survived  Pclass  Name Sex   Age  SibSp  Parch  \
# 0              1         0       3  None   m  22.0      1      0
# 2              3         1       3  None   f  26.0      0      0
# 4              5         0       3  None   m  35.0      0      0
# 5              6         0       3  None   m   NaN      0      0
# 7              8         0       3  None   m   2.0      3      1
# ..           ...       ...     ...   ...  ..   ...    ...    ...
# 884          885         0       3  None   m  25.0      0      0
# 885          886         0       3  None   f  39.0      0      5
# 886          887         0       2  None   m  27.0      0      0
# 888          889         0       3  None   f   NaN      1      2
# 890          891         0       3  None   m  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 2    STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
age_36[['Name']]
# Out:
#                                                   Name
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                              McCarthy, Mr. Timothy J
# 11                            Bonnell, Miss. Elizabeth
# 13                         Andersson, Mr. Anders Johan
# 15                    Hewlett, Mrs. (Mary D Kingcome)
# ..                                                 ...
# 865                           Bystrom, Mrs. (Karolina)
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873                        Vander Cruyssen, Mr. Victor
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885               Rice, Mrs. William (Margaret Norton)
#
# [195 rows x 1 columns]

# %%
df1.loc[df1['Age']>36, "Name"]
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
# 13                           Andersson, Mr. Anders Johan
# 15                      Hewlett, Mrs. (Mary D Kingcome)
#                              ...
# 865                             Bystrom, Mrs. (Karolina)
# 871     Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 195, dtype: object

# %%
# df1.iloc[df1['Age']>36, "Name"]

# %%
df1[10:25]
# Out:
#     PassengerId  Survived  Pclass  \
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# ...

# %%
df1.iloc[9:25, 2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                   Hewlett, Mrs. (Mary D Kingcome)   female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
df_ret = pd.read_excel("./Chapter 7 - Internet Exercise 2 - Online Retail.xlsx")

# %%
df_ret.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
def glipse(data):
    head = data.head()
    tail = data.tail()
    info = data.info()
    return(head,tail,info)

# %%
glipse(df_ret)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB
# (  InvoiceNo StockCode                          Description  Quantity  \
#  0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
#  1    536365     71053                  WHITE METAL LANTERN         6
#  2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# ...

# %%
df1.median()
# Out:
# C:\Users\amalv\AppData\Local\Temp\ipykernel_23128\2279417019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# PassengerId    446.0000
# Survived         0.0000
# Pclass           3.0000
# Age             28.0000
# SibSp            0.0000
# Parch            0.0000
# Fare            14.4542
# dtype: float64

# %%
print(df1.skew(numeric_only=True))
# Out:
# PassengerId    0.000000
# Survived       0.478523
# Pclass        -0.630548
# Age            0.389108
# SibSp          3.695352
# Parch          2.749117
# Fare           4.787317
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# howw to convert to categorical variable

# %%
# df1['Age'] = df['Age'].astype()

# %% [markdown]
# density plot

# %%
df1.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
plt.hist(x="Age",data=df1)
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
# plt.bar(x="PassengerId" ,data=df1,)

# %%
name = pd.Series(["amal","fadhil","sai", "satya", "harshith", "harsh"])
marks = pd.Series([61,22,11,44,55,66])
ab = pd.DataFrame({"name":name, "mark":marks})

# %%
ab = pd.DataFrame({"name":name, "mark":marks})

# %%
ab
# Out:
#        name  mark
# 0      amal    61
# 1    fadhil    22
# 2       sai    11
# 3     satya    44
# 4  harshith    55
# 5     harsh    66

# %%
ab
# Out:
#        name  mark
# 0      amal    61
# 1    fadhil    22
# 2       sai    11
# 3     satya    44
# 4  harshith    55
# 5     harsh    66

# %%
ab.sort_values("mark")
# Out:
#        name  mark
# 2       sai    11
# 1    fadhil    22
# 3     satya    44
# 4  harshith    55
# 0      amal    61
# 5     harsh    66

# %%
# tydy - long to wide and wide to lonhg
# #

# %%
# ?innerjoint
# Out:
# Object `innerjoint` not found.

# %%
? reshape to do
# Out:
# Object ` reshape to do` not found.

# %%
# df1["Name"] = df1.Name.lowr case

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1[df1['Name']=='Dooley, Mr. Patrick']
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891         0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
# df1['Name'] = df1['Name'].rename("NAME")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3  None    male  22.0      1      0
# 1              2         1       1  None  female  38.0      1      0
# 2              3         1       3  None  female  26.0      0      0
# 3              4         1       1  None  female  35.0      1      0
# 4              5         0       3  None    male  35.0      0      0
# ..           ...       ...     ...   ...     ...   ...    ...    ...
# 886          887         0       2  None    male  27.0      0      0
# 887          888         1       1  None  female  19.0      0      0
# 888          889         0       3  None  female   NaN      1      2
# 889          890         1       1  None    male  26.0      0      0
# 890          891         0       3  None    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# ...

# %%
df1['Name'].replace("NAME")

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 0              1         0       3  None    male  22.0      1      0
# 1              2         1       1  None  female  38.0      1      0
# 2              3         1       3  None  female  26.0      0      0
# 3              4         1       1  None  female  35.0      1      0
# 4              5         0       3  None    male  35.0      0      0
# ..           ...       ...     ...   ...     ...   ...    ...    ...
# 886          887         0       2  None    male  27.0      0      0
# 887          888         1       1  None  female  19.0      0      0
# 888          889         0       3  None  female   NaN      1      2
# 889          890         1       1  None    male  26.0      0      0
# 890          891         0       3  None    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# ...

# %%
df1['Sex'] = df1['Sex'].replace({'male':'m', 'female':'f'})

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  Name Sex   Age  SibSp  Parch  \
# 0              1         0       3  None   m  22.0      1      0
# 1              2         1       1  None   f  38.0      1      0
# 2              3         1       3  None   f  26.0      0      0
# 3              4         1       1  None   f  35.0      1      0
# 4              5         0       3  None   m  35.0      0      0
# ..           ...       ...     ...   ...  ..   ...    ...    ...
# 886          887         0       2  None   m  27.0      0      0
# 887          888         1       1  None   f  19.0      0      0
# 888          889         0       3  None   f   NaN      1      2
# 889          890         1       1  None   m  26.0      0      0
# 890          891         0       3  None   m  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# ...

# %%
# union, limit, df.sample

# %%
df1.sample(10)
# Out:
#      PassengerId  Survived  Pclass  Name     Sex   Age  SibSp  Parch  \
# 889          890         1       1  None    male  26.0      0      0
# 426          427         1       2  None  female  28.0      1      0
# 750          751         1       2  None  female   4.0      1      1
# 787          788         0       3  None    male   8.0      4      1
# 242          243         0       2  None    male  29.0      0      0
# 513          514         1       1  None  female  54.0      1      0
# 714          715         0       2  None    male  52.0      0      0
# 128          129         1       3  None  female   NaN      1      1
# 614          615         0       3  None    male  35.0      0      0
# 284          285         0       1  None    male   NaN      0      0
#
#           Ticket     Fare  Cabin Embarked
# 889       111369  30.0000   C148        C
# 426         2003  26.0000    NaN        S
# 750        29103  23.0000    NaN        S
# ...

# %%
df11 = df1.groupby(by='Sex')

# %%
df11

# %%
df11.mean()
# Out:
#      PassengerId  Survived    Pclass        Age     SibSp     Parch       Fare
# Sex
# f     431.028662  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# m     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702  25.523893

# %%
df11.sum()
# Out:
#      PassengerId  Survived  Pclass       Age  SibSp  Parch        Fare
# Sex
# f         135343       233     678   7286.00    218    204  13966.6628
# m         262043       109    1379  13919.17    248    136  14727.2865

# %%
a = np.random.normal(10)

# %%
a
# Out:
# 10.412910705387038

# %%
rdf = pd.DataFrame(np.random.randn(10,3), columns=['a','b','c'])

# %%
rdf
# Out:
#           a         b         c
# 0 -0.266078 -0.631827  0.023959
# 1 -0.050310 -0.270809  0.607366
# 2 -0.406366  0.811349 -2.044899
# 3 -0.274695  0.738011  1.921630
# 4 -0.353938  0.797712  0.850082
# 5 -0.916254 -0.344270 -0.755684
# 6  0.752406 -0.333384 -1.247338
# 7 -0.345612  1.666602  1.674090
# 8  0.537152 -0.908949 -0.475678
# 9  0.498378  0.393546  1.387929

# %%
df.apply()
