# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
std_prf = pd.read_csv("./student_data.csv")

# %%
# def glimpse(data):
#     head = std_prf.head()
#     tail = std_prf.tail()
#     shape = std_prf.shape
#     desc = std_prf.describe()
#     return(head ,tail, shape, desc)

# glimpse(std_df)

# %%
std_prf.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
std_prf.head(20)
# Out:
#    school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0      GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1      GP   F   17       U     GT3       T     1     1   at_home     other
# 2      GP   F   15       U     LE3       T     1     1   at_home     other
# 3      GP   F   15       U     GT3       T     4     2    health  services
# 4      GP   F   16       U     GT3       T     3     3     other     other
# 5      GP   M   16       U     LE3       T     4     3  services     other
# 6      GP   M   16       U     LE3       T     2     2     other     other
# 7      GP   F   17       U     GT3       A     4     4     other   teacher
# 8      GP   M   15       U     LE3       A     3     2  services     other
# 9      GP   M   15       U     GT3       T     3     4     other     other
# 10     GP   F   15       U     GT3       T     4     4   teacher    health
# ...

# %%
std_prf.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
std_prf.shape
# Out:
# (395, 33)

# %%
std_prf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
std_prf.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
std_prf.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# let's make the dataset small

std_df = std_prf[['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'traveltime', 'studytime',
       'failures','internet', 'romantic', 'famrel', 'freetime', 'health', 'absences', 'G1', 'G2', 'G3']]

# %%
std_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
std_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 23 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    category
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    category
#  4   famsize     395 non-null    category
#  5   Pstatus     395 non-null    category
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  traveltime  395 non-null    int64
#  12  studytime   395 non-null    int64
#  13  failures    395 non-null    int64
#  14  internet    395 non-null    category
#  15  romantic    395 non-null    category
#  16  famrel      395 non-null    int64
#  17  freetime    395 non-null    int64
#  18  health      395 non-null    category
# ...

# %%
std_prf.shape
# Out:
# (395, 33)

# %%
std_df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# traveltime    0
# studytime     0
# failures      0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
std_df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# traveltime    0
# studytime     0
# failures      0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# lets convet into factor variable

std_df[['school','address', 'famsize', 'Pstatus', 'internet', 'romantic', 'health']] = std_df[['school','address', 'famsize', 
                                                                                                'Pstatus', 'internet', 'romantic', 'health']].astype('category')
# Out:
# C:\Users\amalv\AppData\Local\Temp\ipykernel_23848\2536360403.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   std_df[['school','address', 'famsize', 'Pstatus', 'internet', 'romantic', 'health']] = std_df[['school','address', 'famsize',

# %%
# finding data types
std_df.dtypes
# Out:
# school        category
# sex             object
# age              int64
# address       category
# famsize       category
# Pstatus       category
# Medu             int64
# Fedu             int64
# Mjob            object
# Fjob            object
# reason          object
# traveltime       int64
# studytime        int64
# failures         int64
# internet      category
# romantic      category
# famrel           int64
# freetime         int64
# health        category
# absences         int64
# G1               int64
# G2               int64
# G3               int64
# dtype: object

# %%
std_df.age.unique()
# Out:
# array([18, 17, 15, 16, 19, 22, 20, 21], dtype=int64)

# %%
age1 = std_df[std_df.age <20]

# %%
age_count = age1.groupby(['age','sex'])

# %%
age_count.count()
# Out:
#          school  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  reason  \
# age sex
# 15  F        38       38       38       38    38    38    38    38      38
#     M        44       44       44       44    44    44    44    44      44
# 16  F        54       54       54       54    54    54    54    54      54
#     M        50       50       50       50    50    50    50    50      50
# 17  F        58       58       58       58    58    58    58    58      58
#     M        40       40       40       40    40    40    40    40      40
# 18  F        43       43       43       43    43    43    43    43      43
#     M        39       39       39       39    39    39    39    39      39
# 19  F        14       14       14       14    14    14    14    14      14
#     M        10       10       10       10    10    10    10    10      10
#
#          traveltime  ...  failures  internet  romantic  famrel  freetime  \
# age sex              ...
# ...

# %%
count_ag= std_df.groupby(['age', 'sex']).size()
count_ag
# Out:
# age  sex
# 15   F      38
#      M      44
# 16   F      54
#      M      50
# 17   F      58
#      M      40
# 18   F      43
#      M      39
# 19   F      14
#      M      10
# 20   F       1
#      M       2
# 21   M       1
# 22   M       1
# dtype: int64

# %% [markdown]
# age of most student are in between 15 and 19

# %%
count_ag= std_df.groupby(['age']).size()
count_ag
# Out:
# age
# 15     82
# 16    104
# 17     98
# 18     82
# 19     24
# 20      3
# 21      1
# 22      1
# dtype: int64

# %% [markdown]
# we can see age above 19 are somewhat outliers

# %%
# why dont we remove the age greater than 19?

new_df = std_df[std_df['age']<20]
new_df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# # relationship between variables

# %%
for feature_list in std_prf.columns:
    feature = std_prf[feature_list].unique()
    print("#"*25)
    print(f"{feature_list.title()} variables : {feature}  \n count_value : {len(feature)}")
# Out:
# #########################
# School variables : ['GP' 'MS']
#  count_value : 2
# #########################
# Sex variables : ['F' 'M']
#  count_value : 2
# #########################
# Age variables : [18 17 15 16 19 22 20 21]
#  count_value : 8
# #########################
# Address variables : ['U' 'R']
#  count_value : 2
# #########################
# Famsize variables : ['GT3' 'LE3']
#  count_value : 2
# #########################
# Pstatus variables : ['A' 'T']
#  count_value : 2
# #########################
# Medu variables : [4 1 3 2 0]
#  count_value : 5
# #########################
# Fedu variables : [4 1 2 3 0]
#  count_value : 5
# #########################
# Mjob variables : ['at_home' 'health' 'other' 'services' 'teacher']
#  count_value : 5
# #########################
# Fjob variables : ['teacher' 'other' 'services' 'health' 'at_home']
#  count_value : 5
# #########################
# Reason variables : ['course' 'other' 'home' 'reputation']
#  count_value : 4
# ...

# %%
# shall we try group by ??

for i in std_df.columns[:-1]:
    print(std_df[[i, "G3"]].groupby([i]).mean())
    print("-"*25)
    print("\n")
# Out:
#                G3
# school
# GP      10.489971
# MS       9.847826
# -------------------------
#
#
#             G3
# sex
# F     9.966346
# M    10.914439
# -------------------------
#
#
#             G3
# age
# 15   11.256098
# 16   11.028846
# 17   10.275510
# 18    9.548780
# 19    8.208333
# 20   14.000000
# 21    7.000000
# 22    8.000000
# -------------------------
#
#
#                 G3
# address
# R         9.511364
# U        10.674267
# -------------------------
#
#
#                 G3
# famsize
# GT3      10.177936
# LE3      11.000000
# -------------------------
#
#
#                 G3
# Pstatus
# A        11.195122
# T        10.324859
# -------------------------
#
#
#              G3
# Medu
# 0     13.000000
# 1      8.677966
# 2      9.728155
# 3     10.303030
# 4     11.763359
# -------------------------
#
#
#              G3
# Fedu
# 0     13.000000
# 1      9.158537
# 2     10.260870
# 3     10.660000
# 4     11.364583
# -------------------------
#
#
# ...

# %%
std_prf.median()
# Out:
# C:\Users\amalv\AppData\Local\Temp\ipykernel_23848\1080927152.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std_prf.median()
# age           17.0
# Medu           3.0
# Fedu           2.0
# traveltime     1.0
# studytime      2.0
# failures       0.0
# famrel         4.0
# freetime       3.0
# goout          3.0
# Dalc           1.0
# Walc           2.0
# health         4.0
# absences       4.0
# G1            11.0
# G2            11.0
# G3            11.0
# dtype: float64

# %%
# skewness
std_prf.skew()
# Out:
# C:\Users\amalv\AppData\Local\Temp\ipykernel_23848\3534793041.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std_prf.skew()
# age           0.466270
# Medu         -0.318381
# Fedu         -0.031672
# traveltime    1.607029
# studytime     0.632142
# failures      2.387026
# famrel       -0.951882
# freetime     -0.163351
# goout         0.116502
# Dalc          2.190762
# Walc          0.611960
# health       -0.494604
# absences      3.671579
# G1            0.240613
# G2           -0.431645
# G3           -0.732672
# dtype: float64

# %%
std_prf.kurtosis()
# Out:
# C:\Users\amalv\AppData\Local\Temp\ipykernel_23848\1433313491.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   std_prf.kurtosis()
# age           -0.001222
# Medu          -1.090014
# Fedu          -1.198539
# traveltime     2.344190
# studytime     -0.014432
# failures       5.004727
# famrel         1.139772
# freetime      -0.301807
# goout         -0.770250
# Dalc           4.759492
# Walc          -0.790845
# health        -1.014078
# absences      21.719150
# G1            -0.693830
# G2             0.627706
# G3             0.403421
# dtype: float64

# %%
# we can see absent is highly skewed shall me sketch it?

# %% [markdown]
# ## visualisation

# %% [markdown]
# # univariate analysis

# %%
plt.plot(std_prf.absences, data=std_prf)

# %%
plt.hist(x = std_prf.age, bins=10)
plt.title("histogram for absence")
plt.xlabel("age")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
#  we can see the skewness (# positivly skewed)

# %%
sns.boxplot(y=std_prf['age'])
plt.title("outliear analysis")
# Out:
# Text(0.5, 1.0, 'outliear analysis')

# %% [markdown]
# # bivariate analysis

# %%
plt.scatter( x= std_prf.absences, y = std_prf.G1)
plt.title("absences vs mark(G1)")
plt.xlabel("absences")
plt.ylabel("mark (G1)")
plt.show()

# %%
plt.scatter( x= std_prf.G1, y = std_prf.G2)
plt.title("mark(G1) vs mark(G2)")
plt.xlabel("G1")
plt.ylabel("mark (G2)")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=std_prf.G3, y=std_prf.absences, hue=std_prf['sex'])
# Out:
# <AxesSubplot:xlabel='G3', ylabel='absences'>

# %%
sns.boxplot(y=std_prf['absences'])
plt.title("outliear analysis")
# Out:
# Text(0.5, 1.0, 'outliear analysis')

# %%
sns.boxplot(x = std_df.absences, y= std_prf.Pstatus, hue=std_prf.sex)
plt.title("detailed outliear analysis");

# %%
std_prf.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sns.histplot(std_prf['absences'], kde=True, color='r')
# Out:
# <AxesSubplot:xlabel='absences', ylabel='Count'>

# %%
correlation = std_df.corr()
correlation
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# absences    0.175230  0.100285  0.024473   -0.012944  -0.062700  0.063726
# G1         -0.064081  0.205341  0.190270   -0.093040   0.160612 -0.354718
# G2         -0.143474  0.215527  0.164893   -0.153198   0.135880 -0.355896
# G3         -0.161579  0.217147  0.152457   -0.117142   0.097820 -0.360415
#
# ...
