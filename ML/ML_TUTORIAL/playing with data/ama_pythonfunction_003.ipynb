# %%
# q.no(1)
# Create a function that verifies if a supplied value is greater than the given threshold value. 
# For example, if you supply 59 and the threshold is 70, your function must return false.



def varifies_num(threshold,number):
    if ( number > threshold):
        return(False)
    else:
        return(True)

    
threshold = 39
number = 70
varifies_num(threshold, number)
# Out:
# False

# %%
# q.no 2
# Create a sequence of numbers using rnorm(15, mean = 35, sd = 11) and use the function created in the previous question. 
# Use a for loop to accomplish question no. 1 for all 15 numbers generated by rnorm().


def varifies_num(threshold,number):
    my_dict = {}
    for i in number:
        if ( i > threshold):
            my_dict[i] = False
        else:
            my_dict[i] = True
            
    for key, values in my_dict.items():
        print(f"{key} - {values}")
        

a = np.random.normal(35,11,15)
threshold = 39 
varifies_num(threshold,a)
# Out:
# 29.85001829103376 - True
# 22.063389414461913 - True
# 36.97748432766079 - True
# 20.38544535719264 - True
# 35.4042110622896 - True
# 42.246548657671866 - False
# 30.107567947390773 - True
# 52.32885831815545 - False
# 60.00207180564142 - False
# 45.621117341625904 - False
# 52.766328939410606 - False
# 20.78978965934354 - True
# 14.24959668715961 - True
# 18.08610968182961 - True
# 36.70170366952506 - True

# %%
# q.no(3)
# Write a function for the number produced by the following N <- sample(-4:4, 1). 
# Sample a number between -4 and 4 to verify if it is negative, zero, or positive using conditional branching.


a = np.random.randint(-4,5)
a

def samples(a):
    if(a == 0 ):
        print(f"{a}, its a zero !!!")
    elif(a > 0):
        print(f"{a}, its greater than 0 so its a positive number ")
    else :
        print(f"{a}, its less than 0 so its a negative number")
        
samples(a)
# Out:
# -3, its less than 0 so its a negative number

# %%
# q.no(4)
# Consider the vector vect <- c(1, 3, 5, 7, NA, 9, 11, 22, 33). 
# Use the if-else statement to replace NA in vect. Also, obtain the result using a for loop and if statement


vect = [1, 3, 5, 7, None, 9, 11, 22, 33]

for i in range(len(vect)):
    if vect[i] is None:
        vect[i] = 11
print(vect)



x
# Out:
# [1, 3, 5, 7, 11, 9, 11, 22, 33]
