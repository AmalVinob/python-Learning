# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\amalv\anaconda3\jupyter\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\amalv\anaconda3\jupyter\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df = pd.read_csv("./Salary_dataset.csv")
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')

# %%
df.drop(['Unnamed: 0'], axis=1,inplace=True)

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
plt.scatter(data=df,x = 'YearsExperience', y = 'Salary')
plt.title("Relation between slary and experience", fontsize = 16)
plt.xlabel("experience",fontsize = 15)
plt.ylabel("salary", fontsize = 15);

# %%
from sklearn.linear_model import LinearRegression

x = df.drop(['Salary'], axis=1)
y = df['Salary']

lm = LinearRegression()

lm.fit(x,y)

y_pred = lm.predict(x)

print('Coefficients:', lm.coef_)


print('Intercept:', lm.intercept_)


plt.scatter(x, y, color='blue')
plt.plot(x, y_pred, color='red')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Simple Linear Regression')
plt.show()
# Out:
# Coefficients: [9449.96232146]
# Intercept: 24848.203966523208
