# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
data = pd.read_csv("./tips.csv")

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(x= data['day'], y=data['tip'], c = data['size'])

plt.xlabel("days")
plt.ylabel("tips")

plt.title("day vs tip")

plt.colorbar()

# %%
plt.plot(data['tip'])
plt.plot(data['size'])

# %%
data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.lineplot(x=data.sex, y=data.total_bill, data=data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.scatterplot(x= data.day, y = data.tip, hue=data.sex);

# %%
sns.lineplot(x='day', y ='tip', data=data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.lineplot(data=data.drop(['total_bill'], axis=1))
plt.show()

# %%
sns.barplot(x = 'day', y='tip', hue='sex', data=data)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.histplot(x='total_bill', data=data, kde=True, hue='sex');

# %%
from bokeh.plotting import figure, output_file, show
from bokeh.palettes import magma



graph = figure(title = "Bokeh Scatter Graph")

color = magma(256)

graph.scatter(data['total_bill'], data['tip'], color=color)


show(graph)

# %%
sns.scatterplot(data['total_bill'], data['tip'], hue=data['sex'])
# Out:
# C:\Users\amalv\anaconda3\jupyter\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
graph = figure(title = "Bokeh Bar Chart")
 
# reading the database
data = pd.read_csv("tips.csv")
 
# Count of each unique value of
# tip column
df = data['tip'].value_counts()
 
# plotting the graph
graph.line(df, data['tip'])
 
# displaying the model
show(graph)

# %%
graph = figure(title = "Bokeh Bar Chart")
 
# plotting the graph
graph.vbar(data['total_bill'], top=data['tip'], 
           legend_label = "Bill VS Tips", color='green')
 
graph.vbar(data['tip'], top=data['size'], 
           legend_label = "Tips VS Size", color='red')
 
graph.legend.click_policy = "hide"
 
# displaying the model
show(graph)

# %%
import plotly.express as px

# plotting the scatter chart
fig = px.scatter(data, x="day", y="tip", color='sex')
 
# showing the plot
fig.show()
# Out:
# <div>                            <div id="5fd3e049-71ee-4727-a5df-411d041ffbfa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fd3e049-71ee-4727-a5df-411d041ffbfa")) {                    Plotly.newPlot(                        "5fd3e049-71ee-4727-a5df-411d041ffbfa",                        [{"hovertemplate":"sex=Female<br>day=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Female","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Female","orientation":"v","showlegend":true,"x":["Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Thur","Thur","Fri","Fri","Fri","Fri","Fri","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Thur","Thur","Thur","Thur","Thur","Thur",
# ...

# %%
sns.scatterplot(x='day', y='tip', data=data, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
import plotly.graph_objects as px

 
 
plot = px.Figure(data=[px.Scatter(
    x=data['day'],
    y=data['tip'],
    mode='markers',)
])
 
# Add dropdown
plot.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="left",
            buttons=list([
                dict(
                    args=["type", "scatter"],
                    label="Scatter Plot",
                    method="restyle"
                ),
                dict(
                    args=["type", "bar"],
                    label="Bar Chart",
                    method="restyle"
                )
            ]),
        ),
    ]
)
 
plot.show()
# Out:
# <div>                            <div id="e297e2ea-96e0-4321-9097-3f715c86b940" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e297e2ea-96e0-4321-9097-3f715c86b940")) {                    Plotly.newPlot(                        "e297e2ea-96e0-4321-9097-3f715c86b940",                        [{"mode":"markers","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat",
# ...

# %%
# Out:
# <div>                            <div id="37127707-a1ca-4150-8224-0d5fa79ce8ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37127707-a1ca-4150-8224-0d5fa79ce8ae")) {                    Plotly.newPlot(                        "37127707-a1ca-4150-8224-0d5fa79ce8ae",                        [{"mode":"markers","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat",
# ...

# %%
import plotly.graph_objects as px

plot = px.Figure(data= [px.Scatter(
        x = data['day'],
        y = data['tip'],
        mode='markers')])

plot.show()
# Out:
# <div>                            <div id="08e7675d-b172-4c6e-a186-7fdc7f43e469" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08e7675d-b172-4c6e-a186-7fdc7f43e469")) {                    Plotly.newPlot(                        "08e7675d-b172-4c6e-a186-7fdc7f43e469",                        [{"mode":"markers","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat",
# ...

# %%
import plotly.express as px

plot = px.scatter_3d(data, x='day', y='tip')
plot.show()
# Out:
# <div>                            <div id="c8fc25bb-33e2-4691-870e-84480b6537b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8fc25bb-33e2-4691-870e-84480b6537b2")) {                    Plotly.newPlot(                        "c8fc25bb-33e2-4691-870e-84480b6537b2",                        [{"hovertemplate":"day=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":["Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sun","Sun","Sun","Sun"
# ...

# %%
import plotly.graph_objects as px

plot = px.Figure(data=[px.Scatter(x = data['day'], y = data['tip'], mode='markers')])

plot.update_layout(
                updatemenus = [
                    dict(
                        type = 'buttons',
                        direction = 'left',
                        buttons = list([
                            dict(
                                args =['type', 'scatter'],
                                label = 'scatter plot',
                                method = 'restyle'
                            ),
                            dict(
                                args =['type', 'bar'],
                                label = 'bar plot',
                                method = 'restyle'
                            )
                            
                        ])
                    )
                ]
)


plot.show()
# Out:
# <div>                            <div id="b70c7620-634b-4df1-9716-cf952d097073" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b70c7620-634b-4df1-9716-cf952d097073")) {                    Plotly.newPlot(                        "b70c7620-634b-4df1-9716-cf952d097073",                        [{"mode":"markers","x":["Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sun","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat","Sat",
# ...

# %%
import plotly.graph_objects as px
import pandas as pd
 
# reading the database
data = pd.read_csv("tips.csv")
 
plot = px.Figure(data=[px.Scatter(
    y=data['tip'],
    mode='lines',)
])
 
plot.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                    step="day",
                    stepmode="backward"),
            ])
        ),
        rangeslider=dict(
            visible=True
        ),
    )
)
 
plot.show()
# Out:
# <div>                            <div id="364e9a80-8cdf-401c-a3e2-918ab91eb3b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("364e9a80-8cdf-401c-a3e2-918ab91eb3b0")) {                    Plotly.newPlot(                        "364e9a80-8cdf-401c-a3e2-918ab91eb3b0",                        [{"mode":"lines","y":[1.01,1.66,3.5,3.31,3.61,4.71,2.0,3.12,1.96,3.23,1.71,5.0,1.57,3.0,3.02,3.92,1.67,3.71,3.5,3.35,4.08,2.75,2.23,7.58,3.18,2.34,2.0,2.0,4.3,3.0,1.45,2.5,3.0,2.45,3.27,3.6,2.0,3.07,2.31,5.0,2.24,2.54,3.06,1.32,5.6,3.0,5.0,6.0,2.05,3.0,2.5,2.6,5.2,1.56,4.34,3.51,3.0,1.5,1.76,6.73,3.21,2.0,1.98,3.76,2.64,3.15,2.47,1.0,2.01,2.09,1.97,3.0,3.14,5.0,2.2,1.25,3.08,4.0,3.0,2.71,3.0,3.4,1.83,5.0,2.03,5.17,2.0,4.0,5.85,3.0,3.0,3.5,1.0,4.3,3.25,4.73,4.0,1.5
# ...

# %%
sns.boxplot(x='Outcome', y='BloodPressure', data=diabetes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15732\845761305.py in <module>
# ----> 1 sns.boxplot(x='Outcome', y='BloodPressure', data=diabetes)
#
# NameError: name 'diabetes' is not defined
