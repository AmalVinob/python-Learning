# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./train.csv")
df
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
plt.plot(df['x'], df['y'])

# %%
df_1 = df.sample(n=10, random_state=42)
df_1
# Out:
#          x           y
# 158  100.0   96.623279
# 500   97.0   94.296334
# 396   20.0   17.135511
# 155   86.0   86.821321
# 321   17.0   17.336816
# 212  100.0  100.015803
# 234   18.0   21.213220
# 289   41.0   41.214699
# 300   75.0   75.489103
# 356   93.0   94.452119

# %%
plt.plot(df_1['x'], df_1['y'])

# %%
plt.scatter(df['x'], df['y'])
plt.legend();
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = sns.load_dataset('iris')

# Create a scatter plot with points colored by species
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris)

# Add labels and title
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title('Scatter Plot of Sepal Length vs Sepal Width with Species Coloring')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
plt.scatter(x=iris['sepal_length'], y= iris['sepal_width'],c='red')
plt.scatter(x=iris['petal_length'], y= iris['sepal_width'],c='green')
plt.scatter(x=iris['sepal_length'], y= iris['petal_length'],c='yellow')

# %%
sns.histplot(x=iris['sepal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>
