# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
 
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_wheather = pd.read_csv("./weatherAUS.csv")

df_wheather.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
df_wheather.shape
# Out:
# (235699, 24)

# %%
df_wheather.shape
# Out:
# (235699, 24)

# %%
df_wheather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235699 entries, 0 to 235698
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           235699 non-null  object
#  1   Location       235699 non-null  object
#  2   MinTemp        231644 non-null  float64
#  3   MaxTemp        231781 non-null  float64
#  4   Rainfall       228600 non-null  float64
#  5   Evaporation    105766 non-null  float64
#  6   Sunshine       96111 non-null   float64
#  7   WindGustDir    218176 non-null  object
#  8   WindGustSpeed  218287 non-null  float64
#  9   WindDir9am     217222 non-null  object
#  10  WindDir3pm     225505 non-null  object
#  11  WindSpeed9am   231012 non-null  float64
#  12  WindSpeed3pm   227077 non-null  float64
#  13  Humidity9am    230180 non-null  float64
#  14  Humidity3pm    225751 non-null  float64
#  15  Pressure9am    209657 non-null  float64
# ...

# %%
df_wheather.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df_wheather.drop(['RISK_MM'], axis=1, inplace=True)

df_wheather.shape
# Out:
# (235699, 23)

# %%
df_wheather.describe().style.background_gradient(cmap="CMRmap")
# Out:
# <style type="text/css">
# #T_646b8_row0_col0, #T_646b8_row0_col1, #T_646b8_row0_col2, #T_646b8_row0_col3, #T_646b8_row0_col4, #T_646b8_row0_col5, #T_646b8_row0_col6, #T_646b8_row0_col7, #T_646b8_row0_col8, #T_646b8_row0_col9, #T_646b8_row0_col10, #T_646b8_row0_col11, #T_646b8_row0_col12, #T_646b8_row0_col13, #T_646b8_row0_col14, #T_646b8_row0_col15 {
#   background-color: #ffffff;
#   color: #000000;
# }
# ...

# %%
df_wheather.isnull().sum()
# Out:
# Date                  0
# Location              0
# MinTemp            4055
# MaxTemp            3918
# Rainfall           7099
# Evaporation      129933
# Sunshine         139588
# WindGustDir       17523
# WindGustSpeed     17412
# WindDir9am        18477
# WindDir3pm        10194
# WindSpeed9am       4687
# WindSpeed3pm       8622
# Humidity9am        5519
# Humidity3pm        9948
# Pressure9am       26042
# Pressure3pm       26018
# Cloud9am         104000
# Cloud3pm         109710
# Temp9am            4100
# Temp3pm            8624
# RainToday          7099
# RainTomorrow       7100
# dtype: int64

# %%
category_var = [var for var in df_wheather.columns if df_wheather[var].dtypes=='O']

print(f"there are {len(category_var)} categorical variable \n")
print(f"the categorical varibles are {category_var}")
# Out:
# there are 7 categorical variable
#
# the categorical varibles are ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
category = df_wheather[category_var]
category.head()
# Out:
#          Date Location WindGustDir WindDir9am WindDir3pm RainToday  \
# 0  2008-12-01   Albury           W          W        WNW        No
# 1  2008-12-02   Albury         WNW        NNW        WSW        No
# 2  2008-12-03   Albury         WSW          W        WSW        No
# 3  2008-12-04   Albury          NE         SE          E        No
# 4  2008-12-05   Albury           W        ENE         NW        No
#
#   RainTomorrow
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No

# %% [markdown]
# rain tomorrow is the trageted variable

# %%
df_wheather[category_var].isnull().sum()
# Out:
# Date                0
# Location            0
# WindGustDir     17523
# WindDir9am      18477
# WindDir3pm      10194
# RainToday        7099
# RainTomorrow     7100
# dtype: int64

# %%
for var in category:
    print(category[var].value_counts())
# Out:
# 2017-07-17    49
# 2015-12-15    49
# 2015-12-03    49
# 2015-12-04    49
# 2015-12-05    49
#               ..
# 2007-11-29     1
# 2007-11-28     1
# 2007-11-27     1
# 2007-11-26     1
# 2008-01-31     1
# Name: Date, Length: 5324, dtype: int64
# Canberra            5324
# Sydney              5232
# Darwin              5081
# Hobart              5081
# Brisbane            5081
# Melbourne           5081
# Perth               5080
# Wollongong          4928
# AliceSprings        4928
# Launceston          4928
# Townsville          4928
# GoldCoast           4928
# Cairns              4928
# Albury              4928
# Tuggeranong         4927
# Albany              4927
# MountGambier        4927
# Penrith             4927
# Ballarat            4926
# Bendigo             4919
# MountGinini         4916
# Williamtown         4897
# Richmond            4897
# Cobar               4897
# CoffsHarbour        4897
# Moree               4897
# Woomera             4897
# ...

# %%
cat1 = [var for var in category if df_wheather[var].isnull().sum() != 0]

# %%
print(df_wheather[cat1].isnull().sum())
# Out:
# WindGustDir     17523
# WindDir9am      18477
# WindDir3pm      10194
# RainToday        7099
# RainTomorrow     7100
# dtype: int64

# %%
for var in category:
    print(df_wheather[var].value_counts())
# Out:
# 2017-07-17    49
# 2015-12-15    49
# 2015-12-03    49
# 2015-12-04    49
# 2015-12-05    49
#               ..
# 2007-11-29     1
# 2007-11-28     1
# 2007-11-27     1
# 2007-11-26     1
# 2008-01-31     1
# Name: Date, Length: 5324, dtype: int64
# Canberra            5324
# Sydney              5232
# Darwin              5081
# Hobart              5081
# Brisbane            5081
# Melbourne           5081
# Perth               5080
# Wollongong          4928
# AliceSprings        4928
# Launceston          4928
# Townsville          4928
# GoldCoast           4928
# Cairns              4928
# Albury              4928
# Tuggeranong         4927
# Albany              4927
# MountGambier        4927
# Penrith             4927
# Ballarat            4926
# Bendigo             4919
# MountGinini         4916
# Williamtown         4897
# Richmond            4897
# Cobar               4897
# CoffsHarbour        4897
# Moree               4897
# Woomera             4897
# ...

# %%
# lets check the cardinality

for var in category:
    print(var, 'contains', len(df_wheather[var].unique()),'labels')
# Out:
# Date contains 5324 labels
# Location contains 49 labels
# WindGustDir contains 17 labels
# WindDir9am contains 17 labels
# WindDir3pm contains 17 labels
# RainToday contains 3 labels
# RainTomorrow contains 3 labels

# %%
# feture engineering of date varibale


df_wheather['Date'] = pd.to_datetime(df_wheather['Date'])

# %%
df_wheather['years'] = df_wheather['Date'].dt.year

# %%
df_wheather['month'] = df_wheather['Date'].dt.month

# %%
df_wheather['Day'] = df_wheather['Date'].dt.day

# %%
df_wheather
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1      2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2      2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3      2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4      2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...           ...      ...      ...      ...       ...          ...       ...
# 235694 2023-09-25    Uluru     15.5     33.8       0.0          NaN       NaN
# 235695 2023-09-26    Uluru     15.0     34.1       0.0          NaN       NaN
# 235696 2023-09-27    Uluru     18.8     33.0       0.0          NaN       NaN
# 235697 2023-09-28    Uluru     19.6     33.6       0.0          NaN       NaN
# 235698 2023-09-29    Uluru     17.2     34.2       0.0          NaN       NaN
#
# ...

# %%
df_wheather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235699 entries, 0 to 235698
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           235699 non-null  datetime64[ns]
#  1   Location       235699 non-null  object
#  2   MinTemp        231644 non-null  float64
#  3   MaxTemp        231781 non-null  float64
#  4   Rainfall       228600 non-null  float64
#  5   Evaporation    105766 non-null  float64
#  6   Sunshine       96111 non-null   float64
#  7   WindGustDir    218176 non-null  object
#  8   WindGustSpeed  218287 non-null  float64
#  9   WindDir9am     217222 non-null  object
#  10  WindDir3pm     225505 non-null  object
#  11  WindSpeed9am   231012 non-null  float64
#  12  WindSpeed3pm   227077 non-null  float64
#  13  Humidity9am    230180 non-null  float64
#  14  Humidity3pm    225751 non-null  float64
#  15  Pressure9am    209657 non-null  float64
# ...

# %%
df_wheather.drop(['Date'], axis=1, inplace= True)

# %%
"Date" in df_wheather
# Out:
# False
