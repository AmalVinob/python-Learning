# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
from PIL import Image

# Open an image file
image_path = "C://Users//amalv//Downloads//download.jpg"
img = Image.open(image_path)

# Display the image (optional)
img.show()

# %%
from PIL import Image
import numpy as np

# Open an image file
image_path = 'C://Users//amalv//Downloads//download.jpg'
img = Image.open(image_path)

# Convert the image to a NumPy array
img_array = np.array(img)

# Display the NumPy array (optional)
print(img_array)
""
# Out:
# [[[  3   7  19]
#   [  3   7  19]
#   [  3   7  19]
#   ...
#   [  4   8  20]
#   [  4   8  20]
#   [  5   9  21]]
#
#  [[  3   7  19]
#   [  3   7  19]
#   [  3   7  19]
#   ...
#   [  3   7  19]
#   [  4   8  20]
#   [  4   8  20]]
#
#  [[  2   6  18]
#   [  2   6  18]
#   [  2   6  18]
#   ...
#   [  3   7  19]
#   [  3   7  19]
#   [  3   7  19]]
#
#  ...
#
#  [[  2   6  18]
#   [  2   6  18]
#   [  2   6  18]
#   ...
#   [ 63  65  78]
#   [ 68  70  82]
#   [ 78  81  90]]
#
#  [[  2   6  18]
#   [  2   6  18]
#   [  2   6  18]
#   ...
#   [ 91  94 109]
#   [ 73  76  91]
#   [ 44  48  60]]
#
#  [[  2   6  18]
#   [  2   6  18]
#   [  2   6  18]
#   ...
#   [ 32  38  54]
#   [ 31  37  53]
#   [ 26  32  46]]]
# ''

# %% [markdown]
# ![titanic](download.jpg)

# %%
# ![titanic](download.jpg)

# %%
import pandas as pd
import numpy as np

# to visualize the dataset
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
print(f"rows are {df.shape[0]} columns are {df.shape[1]}")
# Out:
# rows are 418 columns are 12

# %%
df.describe().style.background_gradient(cmap="CMRmap")
# Out:
# <style type="text/css">
# #T_938df_row0_col0 {
#   background-color: #4d26bf;
#   color: #f1f1f1;
# }
# #T_938df_row0_col1, #T_938df_row0_col2, #T_938df_row0_col3, #T_938df_row0_col4, #T_938df_row0_col5, #T_938df_row7_col0, #T_938df_row7_col6 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_938df_row0_col6 {
#   background-color: #e6d34f;
#   color: #000000;
# }
# #T_938df_row1_col0, #T_938df_row5_col0 {
#   background-color: #e6d759;
#   color: #000000;
# }
# ...

# %%
df.describe().style.background_gradient(cmap="plasma")
# Out:
# <style type="text/css">
# #T_ff6ab_row0_col0 {
#   background-color: #7e03a8;
#   color: #f1f1f1;
# }
# #T_ff6ab_row0_col1, #T_ff6ab_row0_col2, #T_ff6ab_row0_col3, #T_ff6ab_row0_col4, #T_ff6ab_row0_col5, #T_ff6ab_row7_col0, #T_ff6ab_row7_col6 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_ff6ab_row0_col6 {
#   background-color: #fdac33;
#   color: #000000;
# }
# #T_ff6ab_row1_col0, #T_ff6ab_row5_col0 {
#   background-color: #fdb130;
#   color: #000000;
# }
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin          327
# Age             86
# Fare             1
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# SibSp            0
# Parch            0
# Ticket           0
# Embarked         0
# dtype: int64

# %% [markdown]
# # lets take the % of values

# %%
(df.isnull().sum() / len(df)*100).sort_values(ascending=False)
# Out:
# Cabin          78.229665
# Age            20.574163
# Fare            0.239234
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Embarked        0.000000
# dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(df.isnull(), cbar=False)
# Out:
# <AxesSubplot:>
